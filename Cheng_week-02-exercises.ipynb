# %% [markdown]
# <h1><center> PPOL 5203 Data Science I: Foundations <br><br>
# <font color='grey'>Week 2: Practice Exercise<br><br>
# Tiago Ventura</center></center> <h1>

# %% [markdown]
# ### Question 1: Writing good code!
#
# Consider the Python snippet below that simulates some data, runs a linear regression on the simulated data, and plots the predictors of the regression.
#
# This is a poorly written code. It has the following issues:
#
# - No comments documenting what the code is doing
# - Poor redability
# - Graphs with no meaning
# - lines of code doing multiple things (you could split it up and make it more readable).
#
# As an exercise, provide a refactored code as the solution to this problem. You solution needs to fix all the issues mentioned above. Check the slides if you need help.

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.random.rand(100)
b = 5 + 3*X1 + np.random.normal(size=100)
plt.scatter(a, b, color = 'red')

# %%
# ADD YOUR RESPONSE HERE
import numpy as np #use the package we need : numpy for calculation and plot for graphing 
import matplotlib.pyplot as plt

np.random.seed(522) #set random seed to ensure reproductivity

a=np.random.rand(100)  # generate variable X with size of 100 (any random number between 0 - 100)
b=5+3*a+np.random.normal(size=100) #build the model

plt.scatter(a,b,color='red') #visualizing the relationship indicated in the model
plt.title("Scatterplot for Model: b=5+3a+error term") # add a title for the plot, indicating the model
plt.xlabel("a") # add axis-x to the plot
plt.ylabel("b") # add axis-y to the plot
# Out:
# Text(0, 0.5, 'b')

# %% [markdown]
# ### Question 2: Initialize version control with git.
#
# Create a folder called “Practice” on your local computer. Use the commandline to navigate to that folder. Next, initialize a git repository in that folder. Do all these steps using the commandline

# %%
# ADD YOUR CODE (from Commandline) and Describe your steps HERE
# mkdir Practice   -> first create the folder 
# cd Practice   -> enter the folder 'Practice'
# git init   -> initialize a git repo in this folder 
# output: Initialized empty Git repository in /Users/charlottegao/Practice/.git/   -> new repo created

# %% [markdown]
# ### Question 3: Git
#
# Using the git repository that you created in Question 1. Do the following:
#
# 1. Create a `.txt` named `notes_about_ds5203` using either the commandline or just make this file yourself and move to the folder.
#
# 2. Add that file to the staging area.
#
# 3. Commit that file with a clear commit message
#
# 4. Check to see if the file is staged using git status;
#
# 5. Now update the file (i.e., make some change to it) and stage and commit that change;
#
# 6. Look at your git log to see the two commits you made.

# %%
# ADD YOUR CODE (from Commandline) and Describe your steps HERE

# cd git-in-class-exercise-Cg1419 -> direct to my folder 'in-class-exercise-Cg1419'
# vim notes_about_ds5203.txt  -> create a new .txt file named 'notes_about_ds5203'
# git add notes_about_ds5203.txt  -> add it to staging area
# git commit -m "initial commit for notes_about_ds5203"  -> commit it with a clear message 
# git status  -> check the status 
# I open the file and add some content into the file. 
# git add notes_about_ds5203.txt  -> after updating: add the file to staging area again 
# git -commit -m "First edit made to file notes_about_ds5203.txt"   -> commit the updated one with a clear message
# git log  -> git log to see my two commits 
# output: commit 61ccc1f5879e7510652423c60b13b5b572312753 (HEAD -> main) & commit f28ddc98cf04f0dc948e142b59a50c9b68770c16

# %% [markdown]
# ### Question 3: Github
#
# 1. Create a new repository on your own Github account
#
# 2. Clone the repository at your local machine
#
# 3. Make some changes in your local machine
#
# 4. Push your local changes to your github repository

# %%
# ADD YOUR CODE (from Commandline) and Describe your steps HERE

# git clone https://github.com/Cg1419/week-02-exercise-q3  -> clone the repo from Github (my own repo: week-02-exercise-q3)
# cd week-02-exercise-q3  -> direct to the repo I created 
# vim test_q3.txt  -> create a new .txt file
# ls  -> ensure the file is in the folder 
# git add test_q3.txt  -> add the file to the staging area
# git commit -m "add a new txt file ad my change to local."  -> commit the file with a clear message 
# git push origin main   -> push my local change (creating a .txt file) to my github repo
# git log  -> ensure the push happened with the output: commit b354a70649dd8c9dbb5cf4cbc74530d4e01e1358 (HEAD -> main, origin/main, origin/HEAD)

# %%
# dont care about this!
#!jupyter nbconvert _week-02-exercises.ipynb --to html --template classic
# Out:
# [NbConvertApp] Converting notebook _week-02-exercises.ipynb to html
# [NbConvertApp] Writing 295722 bytes to _week-02-exercises.html
